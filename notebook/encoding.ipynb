# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mohitsandhuria/adult_census_income/main/adult_census.csv")

# %%
data=pd.read_csv("https://raw.githubusercontent.com/mohitsandhuria/Data_Science-Machine_learning/main/data_set/adult.csv",keep_default_na=False,na_values='?',names=['age',"workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","salary"])

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
labler={}
cat_cols=[var for var in data.columns if data[var].dtype=='O']
for i in cat_cols:
    le=LabelEncoder()
    le=le.fit(data[i])
    data[i]=le.transform(data[i])
    labler[i]=le

# %%
labler
# Out:
# {'workclass': LabelEncoder(),
#  'education': LabelEncoder(),
#  'marital-status': LabelEncoder(),
#  'occupation': LabelEncoder(),
#  'relationship': LabelEncoder(),
#  'race': LabelEncoder(),
#  'sex': LabelEncoder(),
#  'native-country': LabelEncoder(),
#  'salary': LabelEncoder()}

# %%
for i in cat_cols:
    data[i]=labler[i].inverse_transform(data[i])

# %%
data
# Out:
#        age       workclass  fnlwgt    education  education-num  \
# 0       39  LabelEncoder()   77516    Bachelors             13
# 1       50  LabelEncoder()   83311    Bachelors             13
# 2       38  LabelEncoder()  215646      HS-grad              9
# 3       53  LabelEncoder()  234721         11th              7
# 4       28  LabelEncoder()  338409    Bachelors             13
# ...    ...             ...     ...          ...            ...
# 32556   27  LabelEncoder()  257302   Assoc-acdm             12
# 32557   40  LabelEncoder()  154374      HS-grad              9
# 32558   58  LabelEncoder()  151910      HS-grad              9
# 32559   22  LabelEncoder()  201490      HS-grad              9
# 32560   52  LabelEncoder()  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
for i in cat_cols:
    data[i]=labler[i].inverse_transform(data[i])

# %%
labler
# Out:
# {'workclass': LabelEncoder(),
#  'education': LabelEncoder(),
#  'marital-status': LabelEncoder(),
#  'occupation': LabelEncoder(),
#  'relationship': LabelEncoder(),
#  'race': LabelEncoder(),
#  'sex': LabelEncoder(),
#  'native-country': LabelEncoder(),
#  'salary': LabelEncoder()}

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
for i in cat_cols:
    data[i]=le.inverse_transform(data[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 for i in cat_cols:
# ----> 2     data[i]=le.inverse_transform(data[i])
#
# NameError: name 'le' is not defined

# %%
data['workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
e
# Out:
# {'workclass': LabelEncoder(),
#  'education': LabelEncoder(),
#  'marital-status': LabelEncoder(),
#  'occupation': LabelEncoder(),
#  'relationship': LabelEncoder(),
#  'race': LabelEncoder(),
#  'sex': LabelEncoder(),
#  'native-country': LabelEncoder(),
#  'salary': LabelEncoder()}

# %%
from pickle import load

# %%
e=load(open("encoder.pkl","rb"))

# %%
cat_cols=[var for var in data.columns if data[var].dtype=='O']
for i in cat_cols:
    data[i]=e[i].transform(data[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py:224, in _encode(values, uniques, check_unknown)
#     223 try:
# --> 224     return _map_to_integer(values, uniques)
#     225 except KeyError as e:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py:164, in _map_to_integer(values, uniques)
#     163 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164 return np.array([table[v] for v in values])
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py:164, in <listcomp>(.0)
#     163 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 164 return np.array([table[v] for v in values])
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_encode.py:158, in _nandict.__missing__(self, key)
#     157     return self.nan_value
# ...

# %%
# Out:
# LabelEncoder()

# %%
from census import utils

# %%
utils.load_objects(file_path="encoder.pkl")
# Out:
# {'workclass': LabelEncoder(),
#  'education': LabelEncoder(),
#  'marital-status': LabelEncoder(),
#  'occupation': LabelEncoder(),
#  'relationship': LabelEncoder(),
#  'race': LabelEncoder(),
#  'sex': LabelEncoder(),
#  'native-country': LabelEncoder(),
#  'salary': LabelEncoder()}
